# %%
import numpy as np
import matplotlib.pyplot as plt
import mido
import subprocess

# %%
# Load data from file
data = np.loadtxt('galaxia_starbust_SED.txt', delimiter=' ', skiprows=1)
data
# Out:
# array([[1.6870000e-02, 3.3065200e+09],
#        [1.8450000e-02, 4.3671100e+09],
#        [2.0180000e-02, 5.8118400e+09],
#        [2.2080000e-02, 7.3681000e+09],
#        [2.4150000e-02, 9.0997200e+09],
#        [2.6410001e-02, 1.0598300e+10],
#        [2.8889999e-02, 1.2266700e+10],
#        [3.1600000e-02, 1.3720700e+10],
#        [3.4570001e-02, 1.4685300e+10],
#        [3.7810001e-02, 1.6076800e+10],
#        [4.1360001e-02, 1.7230600e+10],
#        [4.5239999e-02, 1.7336000e+10],
#        [4.9479999e-02, 1.6877600e+10],
#        [5.4129999e-02, 1.6184900e+10],
#        [5.9200000e-02, 1.5214400e+10],
#        [6.4759998e-02, 1.3515400e+10],
#        [7.0829999e-02, 1.1885300e+10],
#        [7.7479999e-02, 1.1265600e+10],
#        [8.4750000e-02, 1.0831000e+10],
#        [9.2700000e-02, 1.3237600e+10],
#        [1.0140000e-01, 3.4516600e+10],
#        [1.1090000e-01, 1.2298800e+11],
#        [1.2130000e-01, 1.0584600e+11],
#        [1.3270000e-01, 5.7100800e+11],
# ...

# %%
xDat = data['0']
yDat = data['1']

plt.show()
